# %%
#load dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset to pandas dataframe
df = pd.read_csv(r"C:\Users\User\Downloads\McDonald Data Analysis\menu.csv")

# %%
#print the firts 5 rows of data
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
#statistical information 
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
#finding total rows and columns in dataset
df.shape
# Out:
# (260, 24)

# %%
#getting information on dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#finding the null value
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
df.corr()
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
df.pivot_table('Vitamin A (% Daily Value)','Category').plot(kind='bar',stacked=True,color='b')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df.pivot_table('Vitamin C (% Daily Value)','Category').plot(kind='hist',stacked=True,color='r')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(18,11))
sns.heatmap(df.corr(),annot=True,linewidths=5,fmt=' .1f')
# Out:
# <AxesSubplot:>

# %%
df.Calories.plot(kind='hist',bins=40,figsize=(18,11))
plt.xlabel('Calories')
plt.ylabel('Sugar')
# Out:
# Text(0, 0.5, 'Sugar')

# %%
df.plot(kind='scatter',x='Cholesterol',y='Sugars',alpha=0.4,color='m')
plt.xlabel('Cholestrol')
plt.ylabel('Sugars')
plt.show()

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
dataframe = df[['Calories']]
print(type(dataframe))
print('')
series=df['Calories']
print(type(series))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# <class 'pandas.core.series.Series'>

# %%
x = df['Sugars'] > 30
df[x]
# Out:
#                Category                                               Item  \
# 39            Breakfast                                     Cinnamon Melts
# 40            Breakfast                              Fruit & Maple Oatmeal
# 107            Desserts                                   Hot Fudge Sundae
# 108            Desserts                                 Hot Caramel Sundae
# 109            Desserts                                  Strawberry Sundae
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df[(df['Calories']>300) & (df['Total Fat']>15)]
# Out:
#                Category                                               Item  \
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 5             Breakfast                               Steak & Egg McMuffin
# 6             Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# ..                  ...                                                ...
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df[np.logical_and(df['Carbohydrates']>35,df['Calories']>400)]
# Out:
#                Category                                               Item  \
# 6             Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7             Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 11            Breakfast                    Sausage Biscuit (Large Biscuit)
# ..                  ...                                                ...
# 254  Smoothies & Shakes                McFlurry with M&M’s Candies (Snack)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
df.loc[:5,'Carbohydrates']
# Out:
# 0    31
# 1    30
# 2    29
# 3    30
# 4    30
# 5    31
# Name: Carbohydrates, dtype: int64

# %%
df.loc[:5, ["Category","Item"]]
# Out:
#     Category                              Item
# 0  Breakfast                      Egg McMuffin
# 1  Breakfast                 Egg White Delight
# 2  Breakfast                  Sausage McMuffin
# 3  Breakfast         Sausage McMuffin with Egg
# 4  Breakfast  Sausage McMuffin with Egg Whites
# 5  Breakfast              Steak & Egg McMuffin

# %%
df.loc[:3,"Item" :"Cholesterol"] #between Item and Cholesterol
# Out:
#                         Item    Serving Size  Calories  Calories from Fat  \
# 0               Egg McMuffin  4.8 oz (136 g)       300                120
# 1          Egg White Delight  4.8 oz (135 g)       250                 70
# 2           Sausage McMuffin  3.9 oz (111 g)       370                200
# 3  Sausage McMuffin with Egg  5.7 oz (161 g)       450                250
#
#    Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0       13.0                         20            5.0
# 1        8.0                         12            3.0
# 2       23.0                         35            8.0
# 3       28.0                         43           10.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  Cholesterol
# 0                             25        0.0          260
# 1                             15        0.0           25
# 2                             42        0.0           45
# 3                             52        0.0          285

# %%
threshold=sum(df['Calories'])/len(df['Calories'])
print('threshold is', threshold)

df["cal_level"]=["high" if i>threshold else "low" for i in df['Calories']]
df.loc[:15,["cal_level","Calories","Item"]]
# Out:
# threshold is 368.2692307692308
#    cal_level  Calories                                               Item
# 0        low       300                                       Egg McMuffin
# 1        low       250                                  Egg White Delight
# 2       high       370                                   Sausage McMuffin
# 3       high       450                          Sausage McMuffin with Egg
# 4       high       400                   Sausage McMuffin with Egg Whites
# 5       high       430                               Steak & Egg McMuffin
# 6       high       460      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7       high       520        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8       high       410  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9       high       470  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10      high       430                  Sausage Biscuit (Regular Biscuit)
# ...

# %%
df['Calories'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['Trans Fat'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['Cholesterol'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='Carbohydrates (% Daily Value)',y='Carbohydrates')
# Out:
# <AxesSubplot:xlabel='Carbohydrates (% Daily Value)', ylabel='Carbohydrates'>

# %%
print(df['Item'].value_counts(dropna=False))
# Out:
# Egg McMuffin                                        1
# Nonfat Latte (Small)                                1
# Nonfat Latte (Large)                                1
# Nonfat Caramel Latte (Small)                        1
# Nonfat Caramel Latte (Medium)                       1
#                                                    ..
# Chipotle BBQ Snack Wrap (Grilled Chicken)           1
# Honey Mustard Snack Wrap (Crispy Chicken)           1
# Honey Mustard Snack Wrap (Grilled Chicken)          1
# Ranch Snack Wrap (Crispy Chicken)                   1
# McFlurry with Reese's Peanut Butter Cups (Snack)    1
# Name: Item, Length: 260, dtype: int64

# %%
df.boxplot(column='Calories', by='Calcium (% Daily Value)')
# Out:
# <AxesSubplot:title={'center':'Calories'}, xlabel='Calcium (% Daily Value)'>

# %%
data_new=df.head()
data_new
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
melted_data=pd.melt(frame=data_new,id_vars = 'Item',value_vars=['Calories','Protein'])
melted_data
# Out:
#                                Item  variable  value
# 0                      Egg McMuffin  Calories    300
# 1                 Egg White Delight  Calories    250
# 2                  Sausage McMuffin  Calories    370
# 3         Sausage McMuffin with Egg  Calories    450
# 4  Sausage McMuffin with Egg Whites  Calories    400
# 5                      Egg McMuffin   Protein     17
# 6                 Egg White Delight   Protein     18
# 7                  Sausage McMuffin   Protein     14
# 8         Sausage McMuffin with Egg   Protein     21
# 9  Sausage McMuffin with Egg Whites   Protein     21

# %%
melted_data.pivot(index='Item',columns='variable',values='value')
# Out:
# variable                          Calories  Protein
# Item
# Egg McMuffin                           300       17
# Egg White Delight                      250       18
# Sausage McMuffin                       370       14
# Sausage McMuffin with Egg              450       21
# Sausage McMuffin with Egg Whites       400       21

# %%
data1=df.head()
data2=df.tail()
conc_data=pd.concat([data1,data2],axis=0,ignore_index=True)
conc_data
# Out:
#              Category                                               Item  \
# 0           Breakfast                                       Egg McMuffin
# 1           Breakfast                                  Egg White Delight
# 2           Breakfast                                   Sausage McMuffin
# 3           Breakfast                          Sausage McMuffin with Egg
# 4           Breakfast                   Sausage McMuffin with Egg Whites
# 5  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 6  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 7  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 8  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 9  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 0   4.8 oz (136 g)       300                120       13.0
# ...

# %%
data3=df['Calories'].head()
data4=df['Calories from Fat'].head()
conc_data_col=pd.concat([data3,data4],axis=1)
conc_data_col
# Out:
#    Calories  Calories from Fat
# 0       300                120
# 1       250                 70
# 2       370                200
# 3       450                250
# 4       400                210

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df['Cholesterol']=df['Cholesterol'].astype('float64')
df['Serving Size']=df['Serving Size'].astype('category')

# %%
df.dtypes
# Out:
# Category                           object
# Item                               object
# Serving Size                     category
# Calories                            int64
# Calories from Fat                   int64
# Total Fat                         float64
# Total Fat (% Daily Value)           int64
# Saturated Fat                     float64
# Saturated Fat (% Daily Value)       int64
# Trans Fat                         float64
# Cholesterol                       float64
# Cholesterol (% Daily Value)         int64
# Sodium                              int64
# Sodium (% Daily Value)              int64
# Carbohydrates                       int64
# Carbohydrates (% Daily Value)       int64
# Dietary Fiber                       int64
# Dietary Fiber (% Daily Value)       int64
# Sugars                              int64
# Protein                             int64
# Vitamin A (% Daily Value)           int64
# Vitamin C (% Daily Value)           int64
# ...

# %%
data5=df.loc[:,["Calcium (% Daily Value)","Vitamin A (% Daily Value)","Vitamin C (% Daily Value)"]]
data5.plot()
# Out:
# <AxesSubplot:>

# %%
data5.plot(subplots=True)
plt.show()

# %%
df.plot(kind="scatter",x="Calories",y="Vitamin C (% Daily Value)")
plt.show()

# %%
data5.plot(kind='hist',y='Calcium (% Daily Value)',bins=50,range=(0,160))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# histogram subplot with non cumulative and cumulative
fig, axes = plt.subplots(nrows=2,ncols=1)
df.plot(kind = "hist",y = "Calories",bins = 50,range= (0,250),ax = axes[0])
df.plot(kind = "hist",y = "Total Fat (% Daily Value)",bins = 50,range= (0,250),ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\User\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
